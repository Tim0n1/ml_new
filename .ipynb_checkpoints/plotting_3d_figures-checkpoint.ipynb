# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(-5,5, 1000)
y = np.linspace(-5,5, 1000)

z = 2**x+np.sin(y)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121, projection='3d')
#ax1.plot_surface(x, y, z, cmap='viridis')
ax1.scatter(x,y,z)
ax1.set_title('Surface Plot 1')

X, Y = np.meshgrid(x, y)
Z1 = np.sin(np.sqrt(X**2-Y**2))
print(X)

# Second subplot
ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(X, Y, Z1, cmap='plasma')
ax2.scatter(x,y,z)
ax2.view_init(elev=20,azim=10)
ax2.set_title('Surface Plot 2')
# Out:
# [[-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]
#  [-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]
#  [-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]
#  ...
#  [-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]
#  [-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]
#  [-5.         -4.98998999 -4.97997998 ...  4.97997998  4.98998999
#    5.        ]]
# C:\Users\timon\AppData\Local\Temp\ipykernel_12824\4143657637.py:8: RuntimeWarning: invalid value encountered in sqrt
#   Z1 = np.sin(np.sqrt(X**2-Y**2))
# Text(0.5, 0.92, 'Surface Plot 2')
